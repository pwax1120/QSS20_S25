# %% [markdown]
# ## Problem Set 2: Merging and regular expressions
#
# **Total points (without extra credit)**: 30
#
# **Background on the policy context**: here, we're going to use two datasets to practice reshaping, merging, and regular expression patterns. Both datasets relate to the broader issue of which employers might be violating the rights of temporary guestworkers granted visas under the H-2A program. Here are some articles about potential exploitation of guestworkers by firms and inequality caused by minimal oversight:
#
# - News media coverage of labor abuses of temporary guestworkers: https://www.buzzfeednews.com/article/kenbensinger/the-pushovers
# - GAO report on labor abuses of temporary guestworkers: https://www.gao.gov/products/gao-15-154
#
# The following datasets are located in `pset2_inputdata` (need to unzip):
#
# - `jobs_clean`: a dataset of guestworker jobs posted by many employers, some of whom have been debarred (banned) from the program for labor abuses; others not debarred
# - `debar`: a dataset of employers who committed violations of labor regulations meant to protect temporary guestworkers
#
#
# You can view a codebook here: https://docs.google.com/spreadsheets/d/1rF9GJEC8pPKxipD0TsoG9DVdqz3EJ-b-BHEtyioAX7I/edit?usp=sharing

# %%
## helpful packages
import pandas as pd
import numpy as np
import random
import re
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Reshaping data (13 points total)

# %% [markdown]
# Load the following dataset stored in `pset2_inputdata`: `debar.csv`
#
# This represents employers temporarily banned from hiring workers (debar.csv); call this `debar`
#
#
# View the head()

# %%
## your code here
debar = pd.read_csv("~/Desktop/QSS20_S25/problemsets/pset2/pset2_inputdata/debar.csv")
debar.head()
# Out:
#                                Name     City, State  \
# 0                    J&J Harvesting       Leads, ND
# 1            Stahlman Apiaries, Inc       Selby, SD
# 2                     Trust Nursery     Pulaski, NY
# 3             Anton Fertilizer Inc.     Dighton, KS
# 4  Great Plains Fluid Service, Inc.  Greensburg, KS
#
#                                         Violation Duration Start date  \
# 0  Failure to respond to audit (partial response)  2 years  1/19/2014
# 1  Failure to respond to audit (partial response)   1 year  2/19/2015
# 2  Failure to respond to audit (partial response)   1 year  3/21/2014
# 3       Failure to respond to audit (no response)  2 years  3/30/2014
# 4       Failure to respond to audit (no response)  2 years  3/30/2014
#
#     End date
# 0  1/18/2016
# 1  2/14/2016
# 2  3/20/2015
# 3  3/29/2016
# 4  3/29/2016

# %% [markdown]
# ## 1.1 (1 point)
#
# Print the number of rows in `debar` versus the number of unique employer names (`Name`). Is there one row per employer or multiple rows for some employers?

# %%
## your code here
len(debar)
unique_employers = debar["Name"].nunique()
unique_employers
# Out:
# 114
# 98

# %% [markdown]
# Since there are 114 rows and 98 employers there must be multiple rows for some employers

# %% [markdown]
# ## 1.2 Investigating duplicated rows (2 points)
#
# A. Create a new column in `debar`--`is_repeated`-- that tells us whether an employer (`Name`) is repeated > 1 times
#
# *Hint*: there are multiple ways to solve this but some possibilities to get the list of names that are repeated are:
# - Using value_counts() on the `Name` variable and extracting the index from that value counts
# - Using groupby to count the rows attached to one name
#
# B. Print the rows where `is_repeated == True` and interpret
#
# C. Subset to the rows where `is_repeated == True` and save that data as `mult_debar`. Print the head() and shape

# %%
## your code here
#A
repeated_names = debar["Name"].value_counts()
repeated_names = repeated_names[repeated_names > 1].index

debar["is_repeated"] = debar["Name"].isin(repeated_names)

# %%
#B
print(debar[debar["is_repeated"]==True])
# Out:
#                                         Name       City, State  \
# 6                    Annabella Land & Cattle     Annabella, UT
# 7                        Autumn Hill Orchard        Groton, MA
# 8      Caddo Creek Ranch, dba Paradise Ranch         Caddo, TX
# 11                     Loewen Harvesting LLC   Brownsville, TX
# 12               Rollo Farm Labor Contractor         Miami, FL
# 14                             Sharon Mathis        Tifton, GA
# 15                                 SRT Farms        Morton, TX
# 16                               Mark Duncan     Roosevelt, UT
# 17          Maple Ridge Custom Services, LLC     Altheimer, AK
# 18                                 F&W Farms       Ingalls, KS
# 19                        Cisco Produce Inc.         Cairo, GA
# 21   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 24               Rollo Farm Labor Contractor         Miami, FL
# 25                     Loewen Harvesting LLC    Brownfield, TX
# 28     Caddo Creek Ranch, dba Paradise Ranch      Caddo, Texas
# 29                       Autumn Hill Orchard        Groton, MA
# 30                   Annabella Land & Cattle   Annabella, Utah
# 31                      Macky and Brad Farms        Plains, TX
# 51   Old Tree Farms/Verpaalen Custom Service         Volga, SD
# 55                      Macky and Brad Farms        Plains, TX
# 56                        Cisco Produce Inc.         Cairo, GA
# 58                                 F&W Farms       Ingalls, KS
# 59          Maple Ridge Custom Services, LLC     Altheimer, AR
# 60                               Mark Duncan     Roosevelt, UT
# 61                                 SRT Farms        Morton, TX
# 62                             Sharon Mathis        Tifton, GA
# 73                              Xavier Horne    Lyons, Georgia
# 89                              Xavier Horne    Lyons, Georgia
# 103                         Dove Creek Farms  Mount Vernon, TX
# 106                             Turner Farms         Healy, KS
# 109                         Dove Creek Farms  Mount Vernon, TX
# 111                             Turner Farms         Healy, KS
#
#                                              Violation  Duration  Start date  \
# 6                                          Non Payment    1 year    5/9/2014
# 7            Failure to respond to audit (no response)   2 years    7/6/2014
# 8       Failure to respond to audit (partial response)   2 years   7/20/2014
# 11      Failure to respond to audit (partial response)    1 year   8/20/2014
# 12           Failure to respond to audit (no response)   2 years   8/23/2014
# 14           Failure to respond to audit (no response)   2 years  11/16/2014
# 15           Failure to respond to audit (no response)   2 years  11/16/2014
# 16           Failure to respond to audit (no response)   2 years  11/16/2014
# 17      Failure to respond to audit (partial response)   2 years  11/16/2014
# 18      Failure to respond to audit (partial response)   2 years  12/10/2014
# 19           Failure to respond to audit (no response)   2 years  12/10/2014
# 21                                       WHD Debarment   3 years  12/11/2014
# 24          Impeding the Audit Process – Non- Response   2 years   8/23/2014
# 25      Impeding the Audit Process – Partial- Response    1 year   8/20/2014
# 28      Impeding the Audit Process – Partial- Response   2 years   7/20/2014
# 29          Impeding the Audit Process – Non- Response   2 years    7/6/2014
# 30                                         Non-payment    1 year    5/9/2014
# 31           Failure to respond to audit (no response)    1 year   2/13/2015
# 51                                 Wage Hour Debarment   3 years   12/1/2014
# 55      Impeding the Audit Process – Partial- Response    1 year   2/13/2015
# 56          Impeding the Audit Process – Non- Response   2 years  12/10/2015
# 58      Impeding the Audit Process – Partial- Response    1 year  12/10/2014
# 59      Impeding the Audit Process – Partial- Response    1 year  11/16/2014
# 60          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 61          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 62          Impeding the Audit Process – Non- Response   2 years  11/16/2014
# 73                    Non-payment of certification fee    1 year   6/16/2016
# 89                 Failure to respond to audit request   2 years   9/27/2017
# 103                Failure to respond to audit request   2 years    2/9/2018
# 106  Failure to comply with the employer's obligati...  6 months     7/17/19
# 109                Failure to Respond to Audit Request   2 years    2/9/2018
# 111  Failure to comply with the employer's obligati...  7 months     7/17/19
#
#        End date  is_repeated
# 6      5/9/2015         True
# 7      7/5/2016         True
# 8     7/19/2016         True
# 11    8/19/2015         True
# 12    8/22/2016         True
# 14   11/15/2016         True
# 15   11/15/2016         True
# 16   11/15/2016         True
# 17   11/15/2016         True
# 18    12/9/2016         True
# 19    12/9/2016         True
# 21   12/10/2017         True
# 24    8/22/2016         True
# 25    8/19/2015         True
# 28    7/19/2016         True
# 29     7/5/2016         True
# 30     5/8/2015         True
# 31    2/12/2016         True
# 51    12/1/2017         True
# 55    2/12/2016         True
# 56    12/9/2017         True
# 58    12/9/2015         True
# 59   11/15/2015         True
# 60   11/15/2016         True
# 61   11/15/2016         True
# 62   11/15/2016         True
# 73    6/15/2017         True
# 89    9/26/2019         True
# 103    2/8/2018         True
# 106   2/10/2020         True
# 109    2/8/2020         True
# 111     2/10/20         True

# %%
#C
mult_debar= debar[debar["is_repeated"]==True]
mult_debar.head()
mult_debar.shape
# Out:
#                                      Name      City, State  \
# 6                 Annabella Land & Cattle    Annabella, UT
# 7                     Autumn Hill Orchard       Groton, MA
# 8   Caddo Creek Ranch, dba Paradise Ranch        Caddo, TX
# 11                  Loewen Harvesting LLC  Brownsville, TX
# 12            Rollo Farm Labor Contractor        Miami, FL
#
#                                          Violation Duration Start date  \
# 6                                      Non Payment   1 year   5/9/2014
# 7        Failure to respond to audit (no response)  2 years   7/6/2014
# 8   Failure to respond to audit (partial response)  2 years  7/20/2014
# 11  Failure to respond to audit (partial response)   1 year  8/20/2014
# 12       Failure to respond to audit (no response)  2 years  8/23/2014
#
#      End date  is_repeated
# 6    5/9/2015         True
# 7    7/5/2016         True
# 8   7/19/2016         True
# 11  8/19/2015         True
# 12  8/22/2016         True
# (32, 7)

# %% [markdown]
# ## 1.3 Reshape mult_debar to wide to begin filtering out duplicates (4 points)
#
# You want to separate out two cases:
#
# - Cases where the repeat rows for one employer are due to duplicated data
# - Cases where the repeat rows for one employer represent repeated violations for different issues
#
# There are various ways to check duplicates in this data (eg converting `Violation` to lowercase; replacing spelled-out states with two-dig state codes)
#
# We're going to use the simple rule of:
#
# - A row is a duplicate if, within an employer (defined by Name + City, State), the Start date for each row's violation is the same
#
# To begin to check this, reshape `mult_debar` to a wide dataframe (`mult_debar_wide`) with the following columns, treating the `Name` and `City, State` as the index for the pivot:
#
# - Name
# - City, State
# - start_date_viol1
# - start_date_viol2
#
# Print the head and shape

# %%
## your code here
mult_debar_sorted = mult_debar.sort_values(["Name", "City, State", "Start date"])

mult_debar_sorted["violation_number"] = mult_debar_sorted.groupby(["Name", "City, State"]).cumcount() + 1

mult_debar_wide = mult_debar_sorted.pivot(
    index=["Name", "City, State"],
    columns="violation_number",
    values="Start date"
)

mult_debar_wide.columns = ["start_date_viol1","start_date_viol2"]

mult_debar_wide.head()
mult_debar_wide.shape
# Out:
#                                                       start_date_viol1  \
# Name                                  City, State
# Annabella Land & Cattle               Annabella, UT           5/9/2014
#                                       Annabella, Utah         5/9/2014
# Autumn Hill Orchard                   Groton, MA              7/6/2014
# Caddo Creek Ranch, dba Paradise Ranch Caddo, TX              7/20/2014
#                                       Caddo, Texas           7/20/2014
#
#                                                       start_date_viol2
# Name                                  City, State
# Annabella Land & Cattle               Annabella, UT                NaN
#                                       Annabella, Utah              NaN
# Autumn Hill Orchard                   Groton, MA              7/6/2014
# Caddo Creek Ranch, dba Paradise Ranch Caddo, TX                    NaN
#                                       Caddo, Texas                 NaN
# (20, 2)

# %% [markdown]
# ## 1.4 Filter out duplicates from original debar data (6 points)
#
# A. Using `mult_debar_wide`, add a column `is_dup` that takes value of True for cases where start_date_viol1 == start_date_viol2 marking the row as a duplicate
#
# B. Going back to the original long-format data you loaded at the beginning- `debar`
#     - For employers where `is_dup == True` as indicated by your wide-format dataframe, only keep `violnum == viol1`
#     - For all other employers (so is_dup == False and ones we didnt need to check duplicates for), keep all violnum
#     - Remove the `is_repeated` column from the `debar` data
#
# **Hint**: you can complete part B without a for loop; `pd.concat` with axis = 0 (row binding) is one way
#
# Call the resulting dataframe `debar_clean` and print the shape and # of unique employer names

# %%
## your code here
#A
mult_debar_wide["is_dup"] = mult_debar_wide["start_date_viol1"] == mult_debar_wide["start_date_viol2"]
mult_debar_wide = mult_debar_wide.reset_index()

# %%
debar = debar.sort_values(["Name", "City, State", "Start date"])
debar["violation_number"] = debar.groupby(["Name", "City, State"]).cumcount() + 1

#merge dup info from mult_debar_wide into full debar
debar = pd.merge(
    debar,
    mult_debar_wide[["Name", "City, State", "is_dup"]],
    on=["Name", "City, State"],
    how="left"
)

debar["is_dup"] = debar["is_dup"].fillna(False)

#keep only viol 1 for dups, all for others
debar_clean = pd.concat([
    debar[(debar["is_dup"] == True) & (debar["violation_number"] == 1)],
    debar[debar["is_dup"] == False]
], axis=0)

debar_clean.shape
debar_clean["Name"].nunique()
# Out:
# /var/folders/9_/fcykl83s1dncqz69y6vx8b6w0000gn/T/ipykernel_23150/91469115.py:12: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   debar["is_dup"] = debar["is_dup"].fillna(False)
# (105, 9)
# 98

# %% [markdown]
# # 2. Merging and regex (17 points total)

# %% [markdown]
# ## 2.1 Load data on job postings
#
# The previous dataset contains a small subset of employers who faced temporary bans due to violations of H-2A program regulations
#
# Since most of the bans have expired, we're going to see which of those employers posted new H-2A jobs in the first quarter of 2021
#
# Loading the `jobs_clean.csv` data stored in `pset2_inputdata`

# %%
# your code here to load the data 

jobs_clean = pd.read_csv("~/Desktop/QSS20_S25/problemsets/pset2/pset2_inputdata/jobs.csv")
jobs_clean.head()
# Out:
#           CASE_NUMBER                           CASE_STATUS  \
# 0  H-300-20199-721302      Determination Issued - Withdrawn
# 1  H-300-20231-773906  Determination Issued - Certification
# 2  H-300-20231-774123  Determination Issued - Certification
# 3  H-300-20231-774151  Determination Issued - Certification
# 4  H-300-20231-774508  Determination Issued - Certification
#
#              RECEIVED_DATE            DECISION_DATE  \
# 0  2020-07-17 14:50:40.840  2020-10-01 00:00:00.000
# 1  2020-08-20 10:38:15.620  2020-10-01 00:00:00.000
# 2  2020-08-24 15:33:14.340  2020-10-01 00:00:00.000
# 3  2020-08-21 12:08:09.760  2020-10-01 00:00:00.000
# 4  2020-08-20 10:17:34.530  2020-10-01 00:00:00.000
#
#   TYPE_OF_EMPLOYER_APPLICATION H2A_LABOR_CONTRACTOR NATURE_OF_TEMPORARY_NEED  \
# 0          Individual Employer                    N                 Seasonal
# 1          Association - Agent                    N                 Seasonal
# 2          Individual Employer                    N                 Seasonal
# 3          Individual Employer                    N                 Seasonal
# 4          Individual Employer                    Y                 Seasonal
#
#   EMERGENCY_FILING                       EMPLOYER_NAME  \
# 0                Y  Fazio Farms Operating Company, LLC
# 1                N                  Charlie Sunderland
# 2                N                   Michael Rudebusch
# 3                N                        Lodahl Farms
# 4                N             Dunson Harvesting, Inc.
#
#                 TRADE_NAME_DBA  ... ADDENDUM_B_HOUSING_ATTACHED  \
# 0                          NaN  ...                           N
# 1  Panter & Sunderland Nursery  ...                           N
# 2                          NaN  ...                           N
# 3                          NaN  ...                           Y
# 4      Dunson Harvesting, Inc.  ...                           Y
#
#   TOTAL_HOUSING_RECORDS MEALS_PROVIDED MEALS_CHARGED  \
# 0                     1              Y         12.68
# 1                     1              N           NaN
# 2                     1              N           NaN
# 3                     2              N           NaN
# 4                     8              N           NaN
#
#   MEAL_REIMBURSEMENT_MINIMUM MEAL_REIMBURSEMENT_MAXIMUM PHONE_TO_APPLY  \
# 0                      12.68                       55.0    13607017661
# 1                      12.68                       55.0    19318083783
# 2                      12.68                       55.0    19369333827
# 3                      12.68                       55.0    14069637560
# 4                      12.68                       55.0    18632939888
#
#                   EMAIL_TO_APPLY                             WEBSITE_TO_APPLY  \
# 0           faziofarms@gmail.com                                          NaN
# 1                            NaN  https://www.jobs4tn.gov/vosnet/Default.aspx
# 2  fayethlynpitre@rocketmail.com                                          NaN
# 3        lodahl_kelsey@yahoo.com                                          NaN
# 4                            NaN                        www.employflorida.com
#
#    TOTAL_ADDENDUM_A_RECORDS
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         4
#
# [5 rows x 138 columns]

# %% [markdown]
# ##  2.2 Try inner join on employer name  (2 points)
#
# - Use the `EMPLOYER_NAME` field of the `jobs` dataset
# - Use the `Name` field of the `debar_clean` dataset
#
# A. Use pd.merge with an inner join on those fields to see whether there are any exact matches.
#
# B. If there are exact matches, print the row(s) with exact matches

# %%
## your code here
inner = jobs_clean.merge(debar_clean, left_on="EMPLOYER_NAME", right_on="Name", how="inner", indicator=True)

# %%
print(inner)
# Out:
#           CASE_NUMBER                           CASE_STATUS  \
# 0  H-300-20287-876656  Determination Issued - Certification
#
#              RECEIVED_DATE            DECISION_DATE  \
# 0  2020-10-20 09:20:32.010  2020-11-09 00:00:00.000
#
#   TYPE_OF_EMPLOYER_APPLICATION H2A_LABOR_CONTRACTOR NATURE_OF_TEMPORARY_NEED  \
# 0          Individual Employer                    Y                 Seasonal
#
#   EMERGENCY_FILING   EMPLOYER_NAME TRADE_NAME_DBA  ...            Name  \
# 0                Y  Rafael Barajas            NaN  ...  Rafael Barajas
#
#         City, State                         Violation Duration Start date  \
# 0  Sebring, Florida  Non-payment of certification fee   1 year  9/23/2016
#
#     End date is_repeated  violation_number  is_dup  _merge
# 0  9/22/2017       False               1.0   False    both
#
# [1 rows x 148 columns]

# %% [markdown]
# ## 2.3 Targeted regex (10 points total)
#
# You want to see if you can increase the exact match rate with some basic cleaning of each
# of the employer name fields in each dataset

# %% [markdown]
# ### 2.3.1 Converting to upper (2 points)
#
# A. Convert the `EMPLOYER_NAME` and `Name` fields to uppercase using list comprehension rather than df.varname.str.upper() (it's fine to do a separate list comprehension line for each of the two columns)
#
# B. Print a random sample of 15 values of each result
#
# C. Assign the full vector of uppercase names back to the original data, writing over the original `EMPLOYER_NAME` and `Name` columns

# %%
## insert your code to turn into uppercase here
employer_name_2 = [ name.upper() for name in jobs_clean["EMPLOYER_NAME"]]
name_2 = [ name.upper() for name in debar_clean["Name"]]
#employer_name_2, name_2

# %%
## insert your code for the random sample
print(random.sample(employer_name_2, 15))
print(random.sample(name_2, 15))
# Out:
# ['BLUE RIDGE MOUNTAIN DAIRY LLC  ', 'MARK & CHARLYNN LIUZZA FARMS, LLC', 'DANIEL MARCANTEL FARMS, INC', 'BROWN BROTHERS FARMS', 'AMERIGO FARMS, INC.  ', 'JASON LEE YOUNG', 'LINDSKOV-THIEL CHAROLAIS RANCH', 'PREMIUM EMPLOYMENT SERVICES, INC. ', 'BEKKER FARMS', 'STRIPPIN FEATHERS, LLC', 'DORE FARMS', '6 M FARMS, LLC/JAMILLE R. MENARD', 'DEBERARD CATTLE COMPANY LLC.', "FRUGE' AQUAFARMS, INC.", 'LIUZZA PRODUCE FARM, INC.']
# ['AB RANCH', 'TURNER FARMS', 'AGECY I LLC', 'CIRA CORTEZ LOPEZ', 'J&J HARVESTING', 'LESLIE RENEE DREW', 'TRAVIS AND TARA LAMBOURN', 'YESENIA PEREZ', 'DONNA LUCIO', 'JIM AND ANN SHIPLEY WILLIAM SHIPLEY*', 'CADDO CREEK RANCH, DBA PARADISE RANCH', 'WALKER PLACE', 'PETER PETERS', 'JOHN & NETA LEOPKY FARMS', 'OLD TREE FARMS/VERPAALEN CUSTOM SERVICE']

# %%
## insert your code for assigning the uppercase names back to the data
jobs_clean["EMPLOYER_NAME"] = employer_name_2
debar_clean["Name"] = name_2

jobs_clean.head()
debar_clean.head()
# Out:
#           CASE_NUMBER                           CASE_STATUS  \
# 0  H-300-20199-721302      Determination Issued - Withdrawn
# 1  H-300-20231-773906  Determination Issued - Certification
# 2  H-300-20231-774123  Determination Issued - Certification
# 3  H-300-20231-774151  Determination Issued - Certification
# 4  H-300-20231-774508  Determination Issued - Certification
#
#              RECEIVED_DATE            DECISION_DATE  \
# 0  2020-07-17 14:50:40.840  2020-10-01 00:00:00.000
# 1  2020-08-20 10:38:15.620  2020-10-01 00:00:00.000
# 2  2020-08-24 15:33:14.340  2020-10-01 00:00:00.000
# 3  2020-08-21 12:08:09.760  2020-10-01 00:00:00.000
# 4  2020-08-20 10:17:34.530  2020-10-01 00:00:00.000
#
#   TYPE_OF_EMPLOYER_APPLICATION H2A_LABOR_CONTRACTOR NATURE_OF_TEMPORARY_NEED  \
# 0          Individual Employer                    N                 Seasonal
# 1          Association - Agent                    N                 Seasonal
# 2          Individual Employer                    N                 Seasonal
# 3          Individual Employer                    N                 Seasonal
# 4          Individual Employer                    Y                 Seasonal
#
#   EMERGENCY_FILING                       EMPLOYER_NAME  \
# 0                Y  FAZIO FARMS OPERATING COMPANY, LLC
# 1                N                  CHARLIE SUNDERLAND
# 2                N                   MICHAEL RUDEBUSCH
# 3                N                        LODAHL FARMS
# 4                N             DUNSON HARVESTING, INC.
#
#                 TRADE_NAME_DBA  ... ADDENDUM_B_HOUSING_ATTACHED  \
# 0                          NaN  ...                           N
# 1  Panter & Sunderland Nursery  ...                           N
# 2                          NaN  ...                           N
# 3                          NaN  ...                           Y
# 4      Dunson Harvesting, Inc.  ...                           Y
#
#   TOTAL_HOUSING_RECORDS MEALS_PROVIDED MEALS_CHARGED  \
# 0                     1              Y         12.68
# 1                     1              N           NaN
# 2                     1              N           NaN
# 3                     2              N           NaN
# 4                     8              N           NaN
#
#   MEAL_REIMBURSEMENT_MINIMUM MEAL_REIMBURSEMENT_MAXIMUM PHONE_TO_APPLY  \
# 0                      12.68                       55.0    13607017661
# 1                      12.68                       55.0    19318083783
# 2                      12.68                       55.0    19369333827
# 3                      12.68                       55.0    14069637560
# 4                      12.68                       55.0    18632939888
#
#                   EMAIL_TO_APPLY                             WEBSITE_TO_APPLY  \
# 0           faziofarms@gmail.com                                          NaN
# 1                            NaN  https://www.jobs4tn.gov/vosnet/Default.aspx
# 2  fayethlynpitre@rocketmail.com                                          NaN
# 3        lodahl_kelsey@yahoo.com                                          NaN
# 4                            NaN                        www.employflorida.com
#
#    TOTAL_ADDENDUM_A_RECORDS
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         4
#
# [5 rows x 138 columns]
#                     Name       City, State  \
# 10   AUTUMN HILL ORCHARD        Groton, MA
# 30      DOVE CREEK FARMS  Mount Vernon, TX
# 34             F&W FARMS       Ingalls, KS
# 64  MACKY AND BRAD FARMS        Plains, TX
# 68           MARK DUNCAN     Roosevelt, UT
#
#                                          Violation Duration  Start date  \
# 10       Failure to respond to audit (no response)  2 years    7/6/2014
# 30             Failure to respond to audit request  2 years    2/9/2018
# 34  Failure to respond to audit (partial response)  2 years  12/10/2014
# 64       Failure to respond to audit (no response)   1 year   2/13/2015
# 68       Failure to respond to audit (no response)  2 years  11/16/2014
#
#       End date  is_repeated  violation_number  is_dup
# 10    7/5/2016         True               1.0    True
# 30    2/8/2018         True               1.0    True
# 34   12/9/2016         True               1.0    True
# 64   2/12/2016         True               1.0    True
# 68  11/15/2016         True               1.0    True

# %% [markdown]
# ### 2.3.2 Cleaning up punctuation (4 points)
#
# You notice that INC, CO, and LLC are sometimes followed by a period (.) but sometimes not
#
# A. For each dataset, write a regex pattern using `re.sub` to remove the . but only if it's preceded by INC, LLC, or CO
#
# Make sure LLC, INC, CO remain part of the string but just without the dot
#
# B. Test the pattern on the positive and negative example we provide below and print the result. See the Github issue for examples of what to return
#
#
# **Hint**: https://stackoverflow.com/questions/7191209/python-re-sub-replace-with-matched-content

# %%
pos_example_1 = "CISCO PRODUCE INC."
pos_example_2 = "AVOYELLES HONEY CO., LLC"
neg_example = "E.V. RANCH LLP"

# %%
## insert your code here with the regex pattern for part A
regex = r"(?<=(LLC|INC| CO))\."

## insert your code to use re.sub to apply the pattern to the test cases for part B
test_1 = re.sub(regex, "", pos_example_1)
test_2 = re.sub(regex, "", pos_example_2)
test_3 = re.sub(regex, "", neg_example)
test_1, test_2, test_3
# Out:
# ('CISCO PRODUCE INC', 'AVOYELLES HONEY CO, LLC', 'E.V. RANCH LLP')

# %% [markdown]
# ### 2.3.3 (4 points)
#
# Use that pattern in conjunction with `re.sub` and list comprehension to clean the employer name columns in each dataset. Save the new columns as `name_clean` in each. Then, use row subsetting to (1) subset to rows that changed names and (2) for:
#
# - `debar_clean` print the `Name` and `name_clean` columns
# - `jobs` print the `EMPLOYER_NAME` and `name_clean` columns
#
# Make sure to use the uppercase versions of the variables

# %%
## your code here to clean the columns
employer_name_3 = [ re.sub(regex, "", name) for name in jobs_clean["EMPLOYER_NAME"]]
name_3 = [ re.sub(regex, "", name)  for name in debar_clean["Name"]]
name_3, employer_name_3
# Out:
# (['AUTUMN HILL ORCHARD',
#   'DOVE CREEK FARMS',
#   'F&W FARMS',
#   'MACKY AND BRAD FARMS',
#   'MARK DUNCAN',
#   'ROLLO FARM LABOR CONTRACTOR',
#   'SRT FARMS',
#   'SHARON MATHIS',
#   'TURNER FARMS',
#   '69 FARMS LLC',
#   'AB RANCH',
#   'ABE- NANCY FROESE',
#   'AGECY I LLC',
#   'AGECY II, LLC',
#   'ALTENDORF TRANSPORT INC',
#   'ALTERIC JEAN-CHARLES',
#   'ANNABELLA LAND & CATTLE',
#   'ANNABELLA LAND & CATTLE',
#   'ANTON FERTILIZER INC',
#   'AVOYELLES HONEY CO, LLC',
#   'B & R HARVESTING AND PAUL CRUZ (INDIVIDUAL)',
#   'C HANGING L RANCH LLP',
#   'CADDO CREEK RANCH, DBA PARADISE RANCH',
#   'CADDO CREEK RANCH, DBA PARADISE RANCH',
#   'CHRIS ROBINSON',
#   'CIRA CORTEZ LOPEZ',
#   'CISCO PRODUCE INC',
#   'CISCO PRODUCE INC',
#   'CITY PINESTRAW AND HARVESTING',
#   'COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*',
#   'DANECO, LLC',
#   'DAVID C. MARTINEZ',
#   'DAVID JACKSON',
#   'DEAL FAMILY FARM',
#   'DELIA ROJAS',
#   'DIXIE BELL #2',
#   'DONNA LUCIO',
#   'E.V. RANCH LLP',
#   'EVERGREEN PRODUCE',
#   'FIRST AMERICAN HOLDING',
#   'FIRST AMERICAN HOLDINGS',
#   'GERMAN FARMS',
#   'GERONIMO SHEEP CO',
#   'GLENDA HARROD FARMS',
#   'GONZALO FERNANDEZ*',
#   'GREAT PLAINS FLUID SERVICE, INC',
#   'HAITI/USA WORKFORCE, LLC',
#   'IRISH FLATS',
#   'J & L FARMS',
#   'J&J HARVESTING',
#   'JAVIER XISTO ZAPATA',
#   'JEREMY CHANDLER',
#   'JESUS LEDESMA',
#   'JIM AND ANN SHIPLEY WILLIAM SHIPLEY*',
#   'JOHN & NETA LEOPKY FARMS',
#   'JOHN R. COOK',
#   'K W ENTERPRISES',
#   'LOV RANCH CO, LLLP DBA LOV RANCH',
#   'LABATTE FARMS',
#   'LANDMARK LANDSCAPING',
#   'LEONARD SMITH FARMS',
#   'LESLIE COOK',
#   'LESLIE RENEE DREW',
#   'LOEWEN HARVESTING LLC',
#   'LOEWEN HARVESTING LLC',
#   'LOUIE M. ASUMENDI',
#   'M KENESTON CORP',
#   'MAPLE RIDGE CUSTOM SERVICES, LLC',
#   'MAPLE RIDGE CUSTOM SERVICES, LLC',
#   'MELVIN DON UNDERWOOD II',
#   'MONICA SAAVEDRA (AGENT)',
#   'MYRKA MIREYA CARDENAS',
#   'NEMORIO RESENDIZ',
#   'OLD TREE FARMS/VERPAALEN CUSTOM SERVICE',
#   'OLD TREE FARMS/VERPAALEN CUSTOM SERVICE',
#   'OLSON FARMS',
#   'OMEGA LAMB, LLC',
#   'PEACH CREST FARM, LLC',
#   'PETER PETERS',
#   'PROMAX INC',
#   'QUENTIN SCHELL',
#   'RB FARM PICKING INC, DBA RONALD BERNARD',
#   'RB FARM PICKING, INC',
#   'RAFAEL BARAJAS',
#   "REIMER'S INC",
#   'REIMER’S INC',
#   'ROBERT D. TOWLES',
#   'ROSALVA GARCIA',
#   'RUBEN RUIZ (DESOTO HARVESTING)',
#   'SAXTONS RIVER ORCHARDS, INC',
#   'SLASH E.V. RANCH LLP',
#   'STAHLMAN APIARIES, INC',
#   'TODD DAULTON',
#   'TRAVIS AND TARA LAMBOURN',
#   'TRIANGLE J FARMS',
#   'TRINITY LIVESTOCK PARTNERSHIP',
#   'TRUST NURSERY',
#   'VALLEY VIEW ORCHARDS',
#   'VERN STRATTON FARMS',
#   'WALKER PLACE',
#   'XAVIER HORNE',
#   'XAVIER HORNE',
#   'YESENIA PEREZ',
#   'YOLANDA CHAVEZ',
#   'YOLANDA CHAVEZ FARMING'],
#  ['FAZIO FARMS OPERATING COMPANY, LLC',
#   'CHARLIE SUNDERLAND',
#   'MICHAEL RUDEBUSCH',
#   'LODAHL FARMS',
#   'DUNSON HARVESTING, INC',
#   'CUMBERLAND VALLEY NURSERIES INC',
#   "O'CONNOR RANCH LANDS, LLC",
#   'FARM LABOR ASSOCIATION FOR GROWERS, INC',
#   'RKSK FARMS',
#   'CY FARMS, LLC',
#   'KELLER FARMS, INC',
#   'WORLDWIDE HARVESTING COMPANY LLC',
#   'OPTIMUM AGRICULTURE FL LLC',
#   'WEBB RANCH LLC',
#   'MCLAIN FARMS, INC',
#   'RYAN HERRMANN',
#   'HARVESTCO LLC',
#   'BONNIE PLANTS, INC',
#   'B & W QUALITY GROWERS, INC',
#   'HAYS HARVESTING INC',
#   'ROBBIE DEVILLIER FARMS AND SERVICES LLC',
#   'SUNNY SOUTH PACKING COMPANY',
#   'POPLAR RIDGE FARMS GP',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'FC OF ARCADIA, INC',
#   'KB FARMS, LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'FREEMAN HARVESTING ',
#   'WESTERN RANGE ASSOCIATION',
#   'FIDEL T BARAJAS',
#   'PLAINS COTTON COOPERATIVE ASSOCIATION',
#   'PLAINS COTTON COOPERATIVE ASSOCIATION',
#   'PHIL WALTERS',
#   'ELW FARMS, INC ',
#   'ROSE LAND & CATTLE',
#   '20 MILE SHEEP LLC',
#   'HIGH COUNTRY LAMB LLC',
#   'HUMPHREY COKER SEED CO',
#   'SOUTHERN FLAVOR FARMS LP',
#   'ARBRE FARMS ',
#   'CRUM FARMING, INC',
#   'LADY MOON FARMS, INC',
#   'LEHFELDT RAMBOUILLETS',
#   'MCCABE JOINT VENTURE',
#   'REYNA HARVESTING, INC',
#   'AL MEIER',
#   'WALTHER FARMS LLC- GA',
#   'WESTERN RANGE ASSOCIATION',
#   'STODDARD RANCH ',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WRIGHT EQUIPMENT, LLC ',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'CRAIG & SCOTT JONES LIVESTOCK',
#   'AIRO LIVESTOCK LLC',
#   'ANDERSON BROTHERS LIVESTOCK',
#   'BRUSHVALE SEED, INC',
#   'CRISALIDA BERRY FARMS, LLC',
#   'TMG CATTLE',
#   'PETE AND RAMA PARIS FAMILY TRUST',
#   'ROBERTS RANCH',
#   'GREG WILSON',
#   'TEMP.LABOR, LLC',
#   'WEAVER RANCH, INC',
#   'GNA LABOR, LLC',
#   'DERRINGER TRUCKING & HARVESTING, LLC',
#   'BRYAN KRINKE',
#   'BALTAZAR GARCIA HARVESTING & GROVE CARE, INC',
#   'TRIPLE M FRUIT CO, INC',
#   'THE GROWERS COMPANY, INC',
#   'JEROME K. FOLVAG',
#   "MARTINEZ & SON'S TRUCKING, LLC",
#   'THEM BOYZ HARVESTING, LLC',
#   'SERVICIOS AGRICOLAS MEX, INC',
#   '3 D FARMS ',
#   'CHAD & JENNIFER OLSON',
#   'GREG TOPLE FARMS',
#   'ERIC THOMAS LLC',
#   'GARY P. NOEL',
#   'C & J CRAWFISH FARM LLC',
#   'SIGNET BUILDERS, INC',
#   'JUENEMANN CATTLE',
#   'TNT LIVESTOCK',
#   'JULIAN LAND & LIVESTOCK',
#   'SANDY WEBSTER',
#   'JENNINGS FARMS INC',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'BLUE MOUNTAIN CATTLE INC',
#   'WESTERN RANGE ASSOCIATION',
#   'GALLOPS FARM',
#   'YIELD-PRO CROP CONSULTING INC',
#   'D & J PACKING LLC',
#   'ANDALUSIAN, INC',
#   'GIEM RANCHES, INC',
#   'GLENN ECKELBERG',
#   'H2A COMPLETE II, INC ',
#   'THEM BOYZ HARVESTING, LLC',
#   'CENTRAL FRUIT HARVESTING, LLC ',
#   'AG G.R.O. LLC',
#   'S&S JERSEYLAND DAIRY, LLC',
#   'TANNER LEMON',
#   'SHARIDEN FARMS PARTNERSHIP',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'DOUBLE B FARMS & GIN, LLC',
#   'STRIPPIN FEATHERS, LLC',
#   'PLEASANT HILL GRAIN INC ',
#   'GUZMAN & BARRERA HARVESTING, INC',
#   'KEVIN JOHN REINERS',
#   'TREVOR B HAIR',
#   'MICHAEL BLAIN ZAUNBRECHER FARMS',
#   'JUAN CARLOS RAMOS',
#   'JAIME LOPEZ',
#   'DUNSON HARVESTING, INC',
#   'AGRINATURAL GROWER SUPPLY ',
#   'TEMP.LABOR, LLC',
#   'DAISY LANE DAIRY, INC',
#   'JOSE H. MARTINEZ',
#   'ALCO HARVESTING, LLC',
#   'BAYOU FARMS BIN SERVICES & REPAIR, LLC',
#   'TANIMURA & ANTLE FRESH FOODS, INC ',
#   'STAR RANCH OF OZONA, LLC',
#   'ALTMAN SPECIALTY PLANTS, LLC - TX',
#   'K & M FARMING LTD',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'EBIFANIO ALVAREZ',
#   'GREEN HILL FARMS',
#   'WESTERN RANGE ASSOCIATION',
#   'CTM, INC',
#   'RAUSER BROTHERS',
#   'G. CISNEROS HARVESTING, INC',
#   'TY CHARLES GREGOR',
#   'PISTORIUS, INC',
#   'THE SMITH GROUP LLC  ',
#   'JOHN P BERZAS',
#   'RAY KIMBLE BERZAS',
#   'OCF SEEDS, LLC',
#   'VANDERHAM DAIRY #2',
#   'TWIN AG FARMS',
#   'R. LARSON SHEEP CO',
#   'EAT RICE, INC',
#   'PREMIUM PACKING, INC',
#   'KALIR ENTERPRISES INC',
#   'ROBERT RATLIFF',
#   'MCNEILL LABOR MANAGEMENT INC',
#   'TH GRAIN BIN REPAIR, LLC',
#   'LATINO HARVESTING, LLC',
#   'FARM LABOR ASSOCIATION FOR GROWERS, INC',
#   'FRANCO MEDINA HARVESTING',
#   'FREEDOM TREE FARMS, LLC',
#   'GREEN EMPIRE FARMS, INC',
#   'BRANT M BROWN',
#   'ALTMAN SPECIALTY PLANTS, LLC - CA ',
#   'TITMUS FAMILY FARMS',
#   'DEMAND QUALITY, L.L.C.',
#   'ACP FARMS, LLC',
#   'B&G AGRI',
#   'FERNANDO MEZA HARVESTING, INC',
#   'EVERGLADES HARVESTING, INC',
#   'KEVIN JOHN REINERS',
#   'KEIMIG HARVESTING & TRUCKING, LLC',
#   'BIO APPLICATION LLC',
#   'JAMES FARMS JOINT VENTURE',
#   'CHRISTINA GAMEZ',
#   'WESTERN RANGE ASSOCIATION',
#   '2J DONNELL LIVESTOCK LLC',
#   'LUIS ALVAREZ',
#   'TROTWOOD FARM, LLC',
#   'DUNCAN FAMILY FARMS LLC ',
#   'PACIFIC LIVESTOCK INC',
#   'KINZLER ROCKING K FARM',
#   'FOOTHILL PACKING, INC',
#   'MARTIN GRANADOS',
#   'STATEWIDE HARVESTING & HAULING, LLC',
#   'FRESH HARVEST, INC',
#   'FC OF ARCADIA, INC',
#   'VPC PRODUCE, LLC',
#   "NATURE'S GREEN, INC",
#   'FOOTHILL PACKING, INC',
#   'THORNHILL RANCH PARTNERSHIP',
#   'ELKHORN PACKING CO LLC',
#   'CITRUS HARVESTING, INC',
#   'FOOTHILL PACKING, INC',
#   'CRAWFISH CENTER, LLC',
#   'ROBBIE T. GASPARD',
#   'GOMELLO, LLC',
#   'GREEN CIRCLE GROWERS, INC  ',
#   'CABBAGE HARVESTING, LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'ELKHORN PACKING CO LLC',
#   'LITTLE RANCH CO, INC',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'LORI HOHERZ',
#   'CHRIS PALMER',
#   'CASTRO LABOR SOLUTIONS LLC',
#   'MCNEILL LABOR MANAGEMENT INC',
#   'W&J TRUCKING LLC',
#   'AG-MART PRODUCE, INC',
#   'LENNARD AG',
#   'SUN CITRUS HARVESTING, INC',
#   'COOPER PLANTING COMPANY PTR',
#   'JR CUSTOM HARVESTING CO INC ',
#   'ELKHORN PACKING CO LLC',
#   'HARWELL FARMS JV',
#   'OVERLOOK HARVESTING COMPANY, LLC',
#   'FOOTHILL PACKING, INC',
#   'DUNSON HARVESTING, INC',
#   'PGF OPERATING, LLC',
#   'ALEJANDRO NAVARRO',
#   "MARTINEZ & SON'S TRUCKING, LLC",
#   'ROBERT LANDEIS',
#   'CHARLES ISHMAEL',
#   'JFT HARVESTING, INC',
#   'NICHOLAS P. VONDENSTEIN',
#   'PS&J CRAWFISH',
#   'CROSS MOUNTAIN RANCH LIMITED PARTNERSHIP',
#   'WJ CATTLE, LLC',
#   'G.M. HARVESTING, INC',
#   'HIRE US INC',
#   'SOUTHERN GARDENS GROVES CORP. ',
#   'B BAR J INC',
#   'JOEL A. SALGADO',
#   'CLW HARVESTING LLC',
#   'GATOR BRAKE FARM PARTNERSHIP',
#   'JAR FARM PARTNERSHIP',
#   'PACIFIC TOMATO GROWERS, LTD',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'INDACOCHEA SHEEP RANCH',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'MIDWEST AG ELECTRIC INC',
#   'LOVELAND, INC',
#   'FAT CAT LLC',
#   'HONEY LAND FARMS II, LLC',
#   'CISNEROS HARVESTING, INC',
#   'RODRIGUEZ HARVESTING, LLC',
#   'RIGOBERTO BARAJAS',
#   'ZION HARVEST, INC ',
#   'SEBRING CITRUS, INC',
#   'D & K HARVESTING, INC',
#   'CAROLINA AGRICULTURE, LLC',
#   'CHRISTOPHER WEST',
#   'AO HARVESTING, LLC',
#   'LA ALIANZA, LP',
#   'KIRT H RICHINS',
#   'PAUL JACOBS',
#   'GREEN CIRCLE GROWERS, INC  ',
#   'V & S HARVESTING, INC',
#   'LIONEL MOUNIER JR FARM',
#   'PGF OPERATING, LLC',
#   'BAILEY FARMS SOUTH, LLC',
#   'P&L HARVESTING, LLC ',
#   'STACEY ROBERTS',
#   'SIDDOWAY SHEEP CO',
#   'ALEX T DUFURRENA',
#   'RIES FARMS LLC',
#   'LUCAS BURKE WEST',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'VASQUEZ BROTHERS INC',
#   "NATURE'S WAY COMPOST LLC",
#   'DOUBLE J HARVESTING, INC',
#   'CHAPA GLOBAL CONTRACTING, INC',
#   'ALAN VARNER',
#   'TIM GANN',
#   'BLUE RIDGE MOUNTAIN DAIRY LLC  ',
#   'CROSSON FARMS, INC',
#   'M & B LAND AND CATTLE',
#   'LOS OLMOS CATTLE COMPANY, LLC',
#   'FOOTHILL PACKING, INC',
#   'PERI & SONS FARMS OF CALIFORNIA, LLC',
#   'FOOTHILL PACKING, INC',
#   'BENJAMIN M RAMIREZ HARVESTING, INC',
#   'CITRUS HARVESTING, INC',
#   'FOOTHILL PACKING, INC',
#   'VALLEY PRIDE, INC',
#   'ALTMAN SPECIALTY PLANTS, LLC - CA SALINAS',
#   'SERVICIOS AGRICOLAS MEX, INC',
#   'BARRETT HARDEE',
#   'J. GUERRA, LLC',
#   'DC LAND & LIVESTOCK, LLC',
#   'HD PLANTING COMPANY',
#   'ODOM NURSERY CO INC',
#   'DARNALL RANCH',
#   'ROCKING W FARMS PARTNERSHIP',
#   'MAMMOSER FARMS INC',
#   'BIEBER FARMS MANAGEMENT',
#   'HAMILTON FARMS',
#   "FOUR R'S RANCH, LLC",
#   'WILLIAM D PRIMROSE',
#   'ALVARO VARGAS',
#   'LOUISIANA AG GROUP, GP',
#   'BALL BROTHERS SHEEP INC',
#   'RONALD J MOSS',
#   'JOHN ESPIL SHEEP CO INC',
#   'DEL NORTE HARVESTING, LLC',
#   'BLUE TENT FARMS',
#   'DIAMOND SHEEP COMPANY',
#   'CARRIER SUGARBUSH, LLC ',
#   'ALTA CITRUS, LLC',
#   'KLC FARM',
#   'CHAIN SEED COMPANY LLC',
#   'TRIPLE M FRUIT CO, INC',
#   'KELLEY PLANT FARMS',
#   'WESTERN RANGE ASSOCIATION',
#   'CYNTHIA BOLLICH FARMS',
#   'WESTERN RANGE ASSOCIATION',
#   'PARADISE ISLAND INC',
#   'WESTERN RANGE ASSOCIATION',
#   'DOISE CRAWFISH, LLC',
#   'BERZAS BROS. FARM PTR.',
#   'WESTERN RANGE ASSOCIATION',
#   'THREE G TRUCKING, INC',
#   'PITTMAN FARMS II, LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'MIGUEL LEROY LOZANO ',
#   'WESTERN RANGE ASSOCIATION',
#   'DUNCAN FAMILY FARMS LLC ',
#   'JEFFERY JONES',
#   'ROBERT WILKINSON JR',
#   'RJ HARVESTING, INC',
#   'LAZY 3X CATTLE, LLC',
#   'TERRY VAUGHN',
#   'SPECIALTY CROP FARM LABOR CONTRACTORS, LLC',
#   'FRESH HARVEST, INC',
#   "THE NORTH CAROLINA GROWER'S ASSOCIATION, INC",
#   'ELKHORN PACKING CO LLC',
#   'AGRI CREW, LLC ',
#   'ALPHA AGRICULTURAL BUILDERS INC ',
#   'RED HARVESTING INC',
#   'BADILLO BROTHERS, INC',
#   'EMPIRE FARM LABOR CONTRACTOR LLC',
#   'LONE WOLF MANAGEMENT, INC',
#   'BRADLEY LABOR GROUP, LLC',
#   'RP7 ENTERPRISE, LLC',
#   'FIELD BROTHERS FARMS, INC',
#   'DELTA DIRT FARMS',
#   'DUNCAN FAMILY FARMS LLC ',
#   'CHACON SHEEP COMPANY, LLC',
#   'ALEWELT CONCRETE INC ',
#   'BERZAS BROS. FARM PTR.',
#   'LG HERNDON JR. FARMS, INC',
#   'AMERIGO FARMS, INC  ',
#   'FRESH HARVEST, INC',
#   'NATURE FRESH FARMS USA, INC',
#   'KCK FARMS, LLC  ',
#   'RICKY INC',
#   'PEDERSEN FARMS, INC  ',
#   'TM HARVESTING, INC',
#   'C.R. WILSON LAND & CATTLE, LLC',
#   'HOFFMAN HARVESTING',
#   'LIL E-Z FARM, INC',
#   'BEBB FARMS',
#   'WILLIAMS FARMS LLC',
#   "HICKMAN'S FAMILY FARMS",
#   '4 DUB CATTLE COMPANY',
#   'TREW JAMES',
#   'CITRUS HARVESTING, INC',
#   'PACIFIC TOMATO GROWERS, LTD',
#   'TWIN OAKS ',
#   'BORDERLINE FARMS, JV',
#   'DOUBLE B LAND & LIVESTOCK',
#   'ALEWELT CONCRETE INC ',
#   'ALEWELT CONCRETE INC ',
#   'ALEWELT CONCRETE INC ',
#   'DENNY NICKELSON FARMS',
#   'SITZ ANGUS RANCH AND LIVESTOCK OPERATION',
#   'SUN BERRY ORCHARD INC',
#   'ALEWELT CONCRETE INC ',
#   'MARK JOYCE RANCH',
#   'WALTER P RAWL & SONS INC',
#   '701 HARVESTING, LLC',
#   'PGM PACKING, INC ',
#   'AGRO-CARGO LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'FRANCISCO OROZCO',
#   'HEATON PECANS INC',
#   'JORDAN PELTON',
#   'SARA GONZALES',
#   'DOWNHOME FOODS INC',
#   'VALLEY PRODUCE HARVESTING & HAULING CO',
#   'RUSTIN WETTSTEIN FARMS',
#   'BONNIE PLANTS, INC',
#   'P. MARIN HARVESTING, INC',
#   'CROWNOVER FARMS',
#   'TINY SEEDS VILLAGE LLC',
#   'ROBERT HARLAN',
#   'BEAVER DAM FARMS INC',
#   "ABENDROTH'S APPLE RIDGE ORCHARDS LLC",
#   'PBM FARMS LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'TC FARMS PARTNERSHIP ',
#   'DOUG KIZZIRE',
#   'WESTERN RANGE ASSOCIATION',
#   'CRISP CITRUS HARVESTING, LLC',
#   'M & A PRODUCE, LLC',
#   'FARM LABOR ASSOCIATION FOR GROWERS, INC',
#   'JOSE M. GRACIA HARVESTING, INC',
#   'PITTS GIN, LLP',
#   'THE GROWERS COMPANY, INC',
#   'BTB AG LLC',
#   'AUTOMATED HARVESTING LLC',
#   'EB HARVESTING, LLC',
#   'BEAR MOUNTAIN ORCHARDS, INC',
#   'MELIN BROTHERS FARM',
#   'RB HARVESTING, LLC',
#   'AVOYELLES CRAWFISH & SEAFOOD LLC',
#   'RITZ CRAWFISH COMPANY, LLC',
#   'EMPIRE FARM LABOR CONTRACTOR LLC',
#   'BEE IMPORTERS LLC',
#   'EAM HARVESTING LLC',
#   'CLARK & CO',
#   'SG HARVESTING LLC',
#   'EAM HARVESTING, LLC',
#   'HBW FARMS, INC',
#   'WESTERN RANGE ASSOCIATION',
#   'BYRON P. ZAUNBRECHER',
#   'BYRON P. ZAUNBRECHER',
#   'WESTERN RANGE ASSOCIATION',
#   'W&H AG PARTNERS',
#   'CLARENCE ARCHIBALD',
#   'MARVIN OPP FARMS',
#   'D & J AND SONS HARVESTING, INC',
#   'HENRICHSON FEEDYARD, INC',
#   'ERWIN TUPPER',
#   'C & A FARMS',
#   'DEAN KNELL',
#   'FARMERS ORGANICS',
#   'PHILLIP M. HEINEN',
#   'D&L FARMS',
#   'T.A. GUIDRY FARM/TRENT A. GUIDRY',
#   'PALIZZI & SON, INC',
#   'EUGENE N. ZAUNBRECHER',
#   'LUCAS SIMON',
#   'TRIPLE S RICE AND CRAWFISH',
#   'SHELDON ACKERSON',
#   'GIN CITY LAND COMPANY, INC',
#   'FRITEL TRUCKING LLC ',
#   'G. DAVID DALLING',
#   'ROLAND ANDRUS FARMS LLC',
#   'DEL NORTE HARVESTING, LLC',
#   '3H RICE & CATTLE',
#   'NEAL LANDRY FARMS',
#   'TRI BENOIT, LLC',
#   'REYNOLDS GREENHOUSES LLC',
#   'FLOWERS FARMS, LLC',
#   'MORGAN FARMS',
#   'BONNIE PLANTS, INC',
#   'WESTERN RANGE ASSOCIATION',
#   'FOX DAIRY LTD. ',
#   'ROGER BENSON ',
#   'FAMILY FRESH HARVESTING LLC',
#   'RYAN COOK',
#   'TRIANGLE H',
#   'FREDERICKSBURG PEACH COMPANY',
#   'PACE BROTHERS',
#   'FINNEY CATTLE',
#   'ANDY MURPHY',
#   'R & Z FARMS PARTNERSHIP',
#   "PAUL'S NURSERY",
#   'WALTER P RAWL & SONS INC',
#   'F & W FARMS',
#   'ALEWELT CONCRETE INC ',
#   'BLAKE HEBERT CRAWFISH FARM, LLC',
#   'DWIGHT SCHILLING',
#   'MCMILLAN SERVICES LLC',
#   'CITRUS HARVESTING, INC',
#   'CLAY COUNTY CATTLE COMPANY, LLC',
#   'CAELAN LEWIS',
#   'SCHENE ENTERPRISES',
#   'CLAIBORNE MILLER',
#   'WENCK BY-PRODUCT MANAGEMENT LLC ',
#   '701 HARVESTING, LLC',
#   'J.C DOWSON, INC',
#   'CLUCK RANCH INC',
#   'JOSE H. MARTINEZ',
#   'JIMMY W. DURBIN FARMS',
#   'S BAR S RANCH, LLC',
#   'YDOC LAND AND LIVESTOCK',
#   'TRIPLE C FARMS, INC',
#   'VALLEY PRIDE, INC',
#   'HOLLYWOOD FEEDERS LLC',
#   'KENNER SIMMENTAL RANCH',
#   'LORANG FARMS',
#   'DENNIS MICHAEL BERGAN',
#   'PAUL ANDERSON  ',
#   'SUPERIOR CRAWFISH, L. L. C. ',
#   'HARRY L. LAWS & COMPANY, INC',
#   'HOFFPAUIR CRAWFISH COMPANY LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'LAWRENCE MALPERT',
#   'QUIRK RANCH LTD',
#   'JOSE RAMIREZ',
#   'HOMESTEAD CATTLE COMPANY',
#   'JRB, LLC',
#   'H2A COMPLETE II, INC',
#   'BLAZZARD FARMS',
#   'PAUL V JOHNSON',
#   'VERMILLION RANCH LIMITED PARTNERSHIP',
#   '4M FEEDERS LLC',
#   'FLORIDA PACIFIC FARMS, LLC',
#   'ADVANCED AGRICULTURE, INC',
#   'SAM ROBINSON',
#   'B&T FARMS, PARTNERSHIP',
#   'JOSHUA D. PREJEAN',
#   'WALTER P RAWL & SONS INC',
#   'ALPHA AGRICULTURAL BUILDERS, INC',
#   'RIVERDALE OPERATIONS',
#   'TOBY BRADFIELD FARMS',
#   'FRESH TULIPS USA LLC',
#   'TREJO LABOR SERVICE, LLC',
#   'VCH MANAGEMENT, INC',
#   '6 M FARMS, LLC/JAMILLE R. MENARD',
#   'THREE G TRUCKING, INC',
#   'TIMBER LAKE ELK RANCH, LLC',
#   'SB HARVESTING, INC',
#   'VAN ZYVERDEN, INC ',
#   'Y & R HARVESTING INC',
#   'CHAPPELL FARMS INC ',
#   'ARTHUR R. ZOELLNER',
#   'TRIEMY MANAGEMENT SERVICES, INC',
#   'SWEET RIVER COMPANY, LLC',
#   'CIRCLE H CITRUS, INC',
#   'GREEN CIRCLE GROWERS, INC  ',
#   'NANCY B HANKS',
#   'G. F. & P. ZAUNBRECHER FARMS',
#   'DAVID J. WOESTEHOFF',
#   'MOSER FARMS',
#   'FC OF ARCADIA, INC',
#   'JAMES KOKES',
#   'WESTERN RANGE ASSOCIATION',
#   'YACKLEY RANCHES ',
#   'PETER JANSS WALKING J ',
#   'PEART RANCH OPERATION LLC',
#   'LEWIS AND TRACEY KRUTZFELDT',
#   'CACHE RIVER CATTLE CO LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'LA ALIANZA, LP',
#   'WADE FARMS INC',
#   'MAIN CANYON RANCH ',
#   'FRESH TULIPS USA LLC',
#   'DUNCAN FAMILY FARMS LLC ',
#   'DUNN RANCH INC',
#   'H2A COMPLETE II, INC',
#   'FARM OP KUZZENS H2A, LLC',
#   'OPTIMUM AGRICULTURE FL LLC',
#   'GREGORY LIVESTOCK COMPANY',
#   'VALERA BROTHERS CUSTOM HARVESTING',
#   'HUNTSMAN RANCH CO',
#   'WESTERN RANGE ASSOCIATION',
#   'SMYTHE & SONS',
#   'TROY JANGULA',
#   'HARSTAD TRUCKING',
#   'GOLDEN DAKOTA FARMS, LLC',
#   'JOHNSON HARVESTING, INC',
#   'OASIS HARVESTING, INC ',
#   'VAN ZYVERDEN, INC ',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'TEX-LA CRAWFISH, LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'ELKHORN PACKING CO LLC',
#   'MB CRAWFISH LLC',
#   'MB CRAWFISH LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'ADVANCED AGRICULTURE, INC',
#   'ETCHART CUSTOM HAYING',
#   'MICHAEL BEKKER',
#   'CUATRO LIGHT CATTLE COMPANY, LLC',
#   'GUTHRIE GREENHOUSES, LLC',
#   'HASSELSTROM FARM',
#   'DUPLANTIS AG, LLC',
#   'DIAMOND PEAK CATTLE COMPANY',
#   'GAMIO LIVESTOCK',
#   'JENSEN LIVESTOCK LLC',
#   'HUNTSMAN RANCH CO',
#   'HARRAL LIVESTOCK CO LLC',
#   'JIM AND LISA REINICK',
#   'S BARRAGAN HARVEST, INC',
#   'GROWING GREENER LLC',
#   'SOLIMAR EE, LLC ',
#   'TRIANGLE SPRAYING, INC',
#   'NATIVE FOREST NURSERY, LLC',
#   'JOHN IHRY',
#   'MARK & CHARLYNN LIUZZA FARMS, LLC',
#   'ROLLING CREEK PARTNERSHIP',
#   'BOX L RANCH',
#   'MANZANA LLC',
#   'DEBRA SHEHADI',
#   'MILBYS FARMS',
#   'SCHUETT PARTNERSHIP',
#   'BEN SCHERESKY FARM',
#   'DAVID A. HEBERT',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'JACK WEAVER FARMS LLC',
#   'JFT HARVESTING, INC',
#   'DSA FARMS GP',
#   'JOEL KLEIN',
#   'BURNHAM BROS',
#   'KUNZLER SHEEP & CATTLE CO',
#   'WESTERN RANGE ASSOCIATION',
#   'DEBBY CHICK',
#   'WHITT AG SERVICE',
#   'ECOSYSTEM CONCEPTS INC',
#   'FRESH TULIPS USA LLC',
#   'YU AN FARMS CO',
#   'CASEY COULTER',
#   'CHASEN GOAT GRAZING ',
#   'BEEF & BACON DRIVE INC ',
#   'SHAMROCK FARMS',
#   'GUERRY INCORPORATED',
#   'MIKE OR LISA KIMSEY   ',
#   'WESTERN RANGE ASSOCIATION',
#   'SIRI AND SON FARMS',
#   'ALCO HARVESTING, LLC',
#   'SANDRA ARIZMENDI',
#   'ALL REGIONS SERVICES, INC',
#   'TOP NOTCH PORK, LLC',
#   'MICHAEL SHIRLEY',
#   'STEPHEN TOWE',
#   'JOHN J HATZENBUHLER',
#   'BEECH CREEK FARMS, LLC',
#   'VG FARM VENTURES',
#   'S. DERRINGER HARVESTING, INC',
#   'Z AND Z FEEDERS LLP',
#   'LAKE CREEK FARMS',
#   'DAMON STAUFFER',
#   "FRUGE' AQUAFARMS, INC",
#   'MORGAN CRAFT',
#   'WILLIAM B VAN HOOK',
#   'DAVID STEEVES',
#   'LESLIE T BROWN FARMS',
#   'MORTON AG PARTNERSHIP',
#   'DAN EHLIS',
#   'WESTERN RANGE ASSOCIATION',
#   'TESSMAN FARMS',
#   'MARIAN G SORUM',
#   'THOMAS J. HALL',
#   'Y CROSS, INC',
#   'BI-STATE FEEDERS, LLC',
#   'BIDART LIVESTOCK INC',
#   'BENWOOD FARMS',
#   'LKT CATTLE COMPANY',
#   "THE NORTH CAROLINA GROWER'S ASSOCIATION, INC",
#   'ALL REGIONS SERVICES, INC',
#   'CITRUS HARVESTING, INC',
#   'GOLDEN LEGACY STABLE, LLC',
#   'WHEATLAND FARMS',
#   'WIVHOLM FARMS',
#   'SHOTKOSKI HAY FARMS',
#   'GLS PLANTING COMPANY LLC',
#   'E.J.Y CORPORATION',
#   'PERI & SONS FARMS OF CALIFORNIA, LLC',
#   'MAINJOY UNLIMITED LLC 2',
#   'EFREN SUAREZ GARCIA',
#   'CANTON MART FARMS PTR',
#   'ALOIS H CRAMER FARMS',
#   'JRS FARM',
#   'WEST LAND & CATTLE LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'KEPLER CATTLE CO LLC',
#   'JARED BENTON FARMS',
#   'FRESH HARVEST, INC',
#   'JKD FARMS LLC',
#   'WELSTAD LIVESTOCK PARTNERSHIP',
#   'RICELAND PROPERTIES LLC',
#   'D31, LLC',
#   'NATIONAL FOOD CORPORATION',
#   'SORG DAIRY, LLC',
#   'MICHAEL N COMPTON',
#   'JEFFREY HAMILTON',
#   'TRIPLE S FARMS',
#   'CONDREY FARMS',
#   'TAPP LLC',
#   'REGAN R SMITH',
#   'VULGAMORE LAND & CATTLE CO, INC ',
#   'SANDOVAL WHOLESALE, INC',
#   'BLUE POINT PRODUCE LLC',
#   'OWENS RANCH',
#   'CIRCLE P CATTLE',
#   'PREVOST CRAWFISH FARMS LLC',
#   'KYLE HART',
#   'WESTERN RANGE ASSOCIATION',
#   'TESSIER FARMS',
#   'EVERGREEN HONEY CO, INC  ',
#   'EVERGREEN HONEY CO, INC  ',
#   'JACKSON CITRUS, INC',
#   'WESTERN RANGE ASSOCIATION',
#   'LYNN BILLADEAU FARMS, INC',
#   'BAUER LAND & LIVESTOCK',
#   'REDDING FARMS, INC',
#   'O CROP SERVICES',
#   'PETER ARTZ',
#   'JG LABOR HARVESTING, LLC',
#   'BEZNER PARTNERSHIP',
#   'RODRIGUEZ CITRUS HARVESTING, INC',
#   'JOHN LEONARDS FARMS',
#   'LORY FRUIT FARMS, INC',
#   'STATEWIDE HARVESTING & HAULING, LLC',
#   'FORREST ARTHUR ',
#   'OTTO AG INVESTMENTS LLC',
#   'S & T FARMS LLC',
#   'ALFRED KEARL & SONS INC',
#   'CITRUS HARVESTING, INC',
#   'NJ GOMEZA FARMS',
#   'EAM HARVESTING LLC',
#   'EAGLE MOUNTAIN TREE FARM, INC',
#   'FLORIDA GROWERS ASSOCIATION, INC',
#   'BONNIE PLANTS, INC',
#   "BROWNING'S HONEY CO, INC",
#   'BARONE GARDENS LLC',
#   'BARONE GARDENS LLC',
#   'KIRK ROBINSON',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'CRAIG FISHER',
#   'WESTERN RANGE ASSOCIATION',
#   'CONSOLIDATED CITRUS LP',
#   'DANIEL PALMER',
#   'F. MADRID HARVESTING, INC',
#   'MARK ZAUNBRECHER',
#   'MISSOURI RIVER FARMS, INC',
#   'BIG RIVER HONEY LLC',
#   'AA HUAPILLA PRODUCE, LLC',
#   'HERITAGE BERRY LLC',
#   'D CANELA RESOURCES, LLC',
#   'LANCE & LISA FUNK PARTNERSHIP',
#   'NATURAL FERTILIZER',
#   'HINEMAN LAND & CATTLE, INC',
#   'HOFFPAUIR CRAWFISH FARMS/AARON KEITH HOFFPAUIR',
#   ' TIM DEWEY TRUCKING CO',
#   'FOOTHILL PACKING, INC',
#   'COMMERCIAL NURSERY COMPANY INC',
#   'MAASKE LLC',
#   'ASSMAN CATTLE COMPANY',
#   'OLSON CUSTOM HAYING LLC',
#   'DALE HENSGENS FARM',
#   'FARRELL LIVESTOCK ',
#   'HENSGENS CRAWFISH FARMS, LLC',
#   'LAMM BROTHERS, LLC',
#   'BONNIE PLANTS, INC',
#   'BONNIE PLANTS, INC',
#   'HOYT ALTMAN BLUEBERRY FARM LLC',
#   'HICKORY HILL GREENHOUSES INC',
#   'LARSON LIVESTOCK, INC',
#   'CONTINENTAL FLORAL LLC',
#   'PALISADE PEACH SHACK, INC',
#   'JACE SCHILLING',
#   'BROUSSARD FARMS LLC',
#   'JESUS MARTINEZ SANTIBANEZ',
#   'CORNERSTONE FARMS',
#   'TRIPLE T FARMS, LLC',
#   'B & B FARMS OF MAMOU INC',
#   'COUSER CATTLE COMPANY ',
#   'ROARING FORK SHEEP CO',
#   'HICKORY HILL GREENHOUSES INC',
#   'SAUCEDO PINE STRAW LLC',
#   'DAVID OR JANINE FOLEY',
#   'DAVID AND JANINE FOLEY',
#   'FARM OP KUZZENS H2A, LLC',
#   'ALONZO FARMS, INC',
#   'BONNIE PLANTS, INC',
#   'LELAND FRANK HAZELTINE',
#   'BOMAR AGRA ESTATES, LLC',
#   'JAMES AND VIRGINIA KNAPP',
#   'RP7 ENTERPRISE, LLC',
#   'TRIEMY MANAGEMENT SERVICES, INC',
#   'GRAND LOUIS FOUR, INC',
#   'ARP CATTLE CO',
#   'TOP GUN AG, LLC',
#   'TAMIJO BRONSON',
#   'RAFAEL BARAJAS',
#   'SOL HARVESTING LLC',
#   'HEATH PETRY',
#   'LA THERIOT FARMS, LLC',
#   'WESTERN RANGE ASSOCIATION ',
#   'SPRING HILL PRODUCE, LLC',
#   'DUNSON HARVESTING, INC',
#   'PRETTY WATER LLC',
#   'MERCER RANCHES, INC',
#   'ROUGE RIVER FARMS, INC  ',
#   'MCCORMICK ERFLE',
#   'FRANK HOWEY FAMILY FARMS',
#   'SHEB W. CALLAHAN',
#   'OVERLOOK HARVESTING COMPANY, LLC',
#   'MARIA QUINTINO DE PEREZ',
#   'DOUBLE J HARVESTING, INC',
#   'J&M FARMS INC',
#   'RHEA BROTHERS',
#   'ARCH FRINK LLC',
#   'BONNIE PLANTS, INC',
#   'TODD OTAHAL FARMS LLC',
#   'THOMAS HALVERSON',
#   'EICHELBERGER FARMS LLC',
#   'STONEWOOD FARM INC',
#   'BYERS PREMIUM CATTLE',
#   'FAIRCHILD SHEARING LLC',
#   'W L BOBBETT, LLC',
#   'LANTZ FARMS',
#   'JOHN GUIDRY FARMS, LLC',
#   'OUT ON A LIMB MAPLE FARM LLC',
#   'DARRELL SAUL FARMS INC',
#   'BIG BAY FARMS INC',
#   "THE NORTH CAROLINA GROWER'S ASSOCIATION, INC",
#   'E CROSS CATTLE COMPANY INC',
#   'OVERLOOK HARVESTING COMPANY, LLC',
#   'DEL NORTE HARVESTING, LLC',
#   'DEL NORTE HARVESTING, LLC',
#   'NICKOLAUS HEUCHERT',
#   'CATCH-22 TRUCKING LLC',
#   'L. F. FARMS',
#   'GEORGE LEWIS THOMPSON JR',
#   'C&S CATTLE CO',
#   'VINCENT RENNER',
#   'CHRIS PALMER',
#   'DUPRE FARMS',
#   'DURAND PONDS & FARMS, INC',
#   'PHILLIP W. HEBERT',
#   'VENEGAS SHEARING',
#   'LTF III',
#   'OUTDOOR BEE',
#   'DALE ZOERB',
#   'WENDL FEEDLOT INC',
#   'JKA  CATTLE LLC',
#   'SWENSON LAND & CATTLE CO',
#   "MARTIN'S NURSERY, INC",
#   'BERGER CATTLE CO',
#   'HUNTSMAN RANCH CO',
#   'GILBERT ORCHARDS, INC',
#   'S BAR B RANCH',
#   'CHASTAIN-BISHOP CATTLE LLC',
#   'LINDA MACKRILL',
#   'L.S. BARAJAS, INC',
#   'AKS SNOCO LLC',
#   'STEVEN L. HARNAGE',
#   'NORTH MAINE MAPLE, INC',
#   'MCNEILL LABOR MANAGEMENT INC',
#   'ANDREW SMITH COMPANY LLC',
#   'CYPRESS BRAKE PLANTING CO',
#   'TROY FRUGE FARMS',
#   'A & T CRAWFISH FARM, LLC',
#   'WESTERN RANGE ASSOCIATION',
#   'KYLE MILLS FARMS',
#   'AARON CELLEY',
#   'JESSICA WELDON',
#   'CARLSON HARVESTING INC',
#   'ELKHORN PACKING CO LLC',
#   'BRYAN LEONARDS FARMS',
#   'ELMORE TRUCK REPAIR',
#   'DONALD A. LEONARDS',
#   'BRYANT GOSSEN FARMS',
#   'GIROUX ORCHARD LLC',
#   'KUNAFIN LLC',
#   'RACHEL BINA ',
#   'FOOTHILL PACKING, INC',
#   'AQUA FARMS CRAWFISH, INC',
#   'JAMES ENGE',
#   'G & J FARMS PARTNERSHIP',
#   'CALIFORNIA APIARIES LLC',
#   'SETH CHAPPELL',
#   'KOPEC VETERINARY ASSOCIATES, PC.  ',
#   'BONNIE PLANTS, INC',
#   'NICHOLAS W. HUNDLEY',
#   'ARIZONA APIARIES LLC',
#   'DARREL DIRKS FARMS ',
#   'GOSHEN GAP FARM LC',
#   'ATP AGRI-SERVICES INC',
#   'OVERLOOK HARVESTING COMPANY, LLC',
#   'HARDING FARMS',
#   'PALLMAN ENTERPRISES INC',
#   'CHAD BRANDT',
#   'MARIO A VARGAS',
#   'FIRST CLASS FREIGHT INC/KYLA GUTHMILLER',
#   'FELAND BROTHERS FARMS',
#   'CHAD LEJEUNE FARMS',
#   'FAIRCHILD SHEARING LLC',
#   'TRIPLE J FARMS',
#   'LAZY 3X SHEEP COMPANY, LLC',
#   'FRESH HARVEST, INC',
#   'J P HABETZ FAMILY FARMS',
#   'JAMES P. HUNDLEY',
#   'WILLIAM D PRIMROSE',
#   'ADAM R ALT',
#   'ROSS FREDERICK',
#   'CRAMER FARMS, LLC',
#   'CLINT FREYOU FARM',
#   'WADE & MICHELLE BILLADEAU',
#   'PREMIER FARM & RANCH SUPPLY',
#   'DAVID MYERS',
#   'MARK GARY HOME BUILDERS',
#   'NICK TALLEY FARMS',
#   'SAUL MINNOW FARMS, INC',
#   'MJM INC',
#   'MIDDLETON FARMS',
#   'KERRY CALLAHAN FARMS LLC',
#   'STEVE BOYUM',
#   'LLT GROUP',
#   'SEDAN FLORAL, INC',
#   'H 4 CRAWFISH LLC',
#   'ROBERTS RANCH',
#   'BONNIE PLANTS, INC',
#   "YOUNG'S PLANT FARM, INC",
#   'JE COOLEY FARMS INC',
#   'BONNIE PLANTS, INC',
#   'NELSON ANGUS RANCH, LLC',
#   'BRITTON BINA',
#   'KOOPMAN DAIRIES, INC',
#   'LUCKY AG, INC',
#   'WASHITA COTTON',
#   'SPIVEY FARMS',
#   'EVERGLADES PLANTING, LLC',
#   'WALTHER FARMS, LLC - NE',
#   'WALTHER FARMS, LLC - NE',
#   'JODY AND ROBIN THOMAS',
#   'WALTHER FARMS, LLC - NE',
#   'BONNIE PLANTS, INC',
#   'ANDY MIKSA HONEY FARM LLC',
#   "WRIGHT'S TRUCKING LLC   ",
#   'NZ RANCH',
#   'BROUSSARD FARMS LLC',
#   'BONNIE PLANTS, INC',
#   'BRO-BOYZ, LLC',
#   'CAROLINA CREPE MYRTLE & SHADE TREE, LLC',
#   'FARMLAND CONVERSION CONSULTANTS, LLC - FL',
#   'WESTERN RANGE ASSOCIATION',
#   'SOUTH GEORGIA PINESTRAW, INC',
#   'MELISSA AG INC',
#   'PLANT ODYSSEY INC',
#   'BEEROM APIARIES, INC',
#   '21 ANGUS RANCH',
#   'MATTHEW L WEBER',
#   'DEL NORTE HARVESTING, LLC',
#   'HANSEN LIVESTOCK COMPANY',
#   'THORNOCK RANCH LLC',
#   'BONNIE PLANTS, INC',
#   'JUSTIN JONAS',
#   'MAURICE HEARD',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   "O'BRYAN COMPOSTING LLC",
#   'WESTERN RANGE ASSOCIATION',
#   'J&F FARMS INC',
#   'JOHN WIECZOREK HARVESTING',
#   'SIGNET BUILDERS, INC',
#   'SIGNET BUILDERS, INC',
#   'SOUTH BUCK FARM & RANCH',
#   'KELLY M. RAMAGE',
#   'WENDELL ZAUNBRECHER',
#   'BRYANT GOSSEN FARMS',
#   'HIRE US INC',
#   'C & K LINK PARTERSHIP',
#   'ECO ANGUS LLC',
#   "OLSON'S GREENHOUSE GARDENS, INC  ",
#   'WILMER FARMS INC',
#   'CLIFFORD HOOPES',
#   'STOKLEY NURSERY, LLC',
#   'OLVERA TRUCKING CORP.',
#   'OLVERA TRUCKING CORP.',
#   'TRAVIS RICHARD',
#   'DAMON WEIGEL',
#   'EVERGLADES HARVESTING, INC',
#   'DALLAS LAUBE',
#   'TREVINO AG. SERVICES, LLC',
#   'VERONICA R GALLEGOS',
#   'SWEETWATER CREEK HONEY FARM, LLC',
#   'BILLY MAC CATFISH COMPANY',
#   'BAKER ENVIRONMENTAL NURSERY, INC',
#   'E.L. PETERSON RANCH INC',
#   'GILBERT ORCHARDS, INC',
#   'LARSON FARMS',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'WESTERN RANGE ASSOCIATION',
#   'SAUCEDA CONTRACTORS, INC',
#   'ALEX HOLLMAN',
#   'PAUL, INC',
#   'DWAYNE COMPTON',
#   'JANDY OJEDA',
#   'SUNSHINE HONEY BEES LLC  ',
#   'GRIZZLY CRK. RANCH ',
#   ...])

# %%
jobs_clean["name_clean"] = employer_name_3
debar_clean["name_clean"] = name_3

# %%
jobs_clean["name_changed"] = jobs_clean["EMPLOYER_NAME"].str.upper() != jobs_clean["name_clean"]
debar_clean["name_changed"] = debar_clean["Name"].str.upper() != debar_clean["name_clean"]

# %%
## your code here to print the head
job_name_changed = jobs_clean[jobs_clean["name_changed"]]
debar_name_changed = debar_clean[debar_clean["name_changed"]]

print(debar_name_changed[["Name", "name_clean"]])
print(job_name_changed[["EMPLOYER_NAME", "name_clean"]])
# Out:
#                                 Name                       name_clean
# 5           ALTENDORF TRANSPORT INC.          ALTENDORF TRANSPORT INC
# 9              ANTON FERTILIZER INC.             ANTON FERTILIZER INC
# 12          AVOYELLES HONEY CO., LLC          AVOYELLES HONEY CO, LLC
# 19                CISCO PRODUCE INC.                CISCO PRODUCE INC
# 20                CISCO PRODUCE INC.                CISCO PRODUCE INC
# 39                GERONIMO SHEEP CO.                GERONIMO SHEEP CO
# 42  GREAT PLAINS FLUID SERVICE, INC.  GREAT PLAINS FLUID SERVICE, INC
# 80                       PROMAX INC.                       PROMAX INC
# 85                     REIMER'S INC.                     REIMER'S INC
# 86                     REIMER’S INC.                     REIMER’S INC
# 94      SAXTONS RIVER ORCHARDS, INC.      SAXTONS RIVER ORCHARDS, INC
#                                  EMPLOYER_NAME  \
# 4                      DUNSON HARVESTING, INC.
# 7     FARM LABOR ASSOCIATION FOR GROWERS, INC.
# 14                          MCLAIN FARMS, INC.
# 17                         BONNIE PLANTS, INC.
# 18                 B & W QUALITY GROWERS, INC.
# ...                                        ...
# 2700                  HARRAL LIVESTOCK CO. LLC
# 2701                   ECOSYSTEM CONCEPTS INC.
# 2702                        SIDDOWAY SHEEP CO.
# 2705                    SATHER MANAGEMENT INC.
# 2711                   C R KOEHL AND SONS INC.
#
#                                    name_clean
# 4                      DUNSON HARVESTING, INC
# 7     FARM LABOR ASSOCIATION FOR GROWERS, INC
# 14                          MCLAIN FARMS, INC
# 17                         BONNIE PLANTS, INC
# 18                 B & W QUALITY GROWERS, INC
# ...                                       ...
# 2700                  HARRAL LIVESTOCK CO LLC
# 2701                   ECOSYSTEM CONCEPTS INC
# 2702                        SIDDOWAY SHEEP CO
# 2705                    SATHER MANAGEMENT INC
# 2711                   C R KOEHL AND SONS INC
#
# [576 rows x 2 columns]

# %% [markdown]
# ## 2.4 More joins and more cleaning (5 points)
#
# A. Conduct another inner join between `jobs` and `debar_clean` now using the `name_clean` column; print the result. Did the cleaning result in any more employers matched between the two datasets?
#
# B. Create a new column in `debar_clean` called `name_clean_2` that uses regex to take the following name in that dataset:
#
# - `SLASH E.V. RANCH LLP` in the `debar_clean` dataset
#
# And cleans it up so that it matches with this employer in `jobs`
#
# - `SLASH EV RANCH` in the `jobs` dataset
#
# Eg a pattern to remove the dots in the EV and the space+LLP-- you can apply the pattern to all employer names in debar_clean (so don't need to worry about only applying it to that one employer)
#
#
# C. Conduct a left join using `name_clean_2` as the join column where the left hand dataframe is `jobs`; right hand dataframe is `debar_clean`, store the result as a dataframe, and print the rows where the merge indicator indicates the row was found in both dataframe
#
# **Note**: this manual cleaning process is inefficient and helps motivate why talked about fuzzy matching. Fuzzy matching could recognize that Slash EV ranch is a highly similar string to slash ev ranch llp and match them without us needing to use regex to make the strings identical.

# %%
## your code here
inner_2 = jobs_clean.merge(debar_clean, left_on="name_clean", right_on="name_clean", how="inner", indicator=True)

# %%
inner_2
# Out:
#           CASE_NUMBER                           CASE_STATUS  \
# 0  H-300-20287-876656  Determination Issued - Certification
#
#              RECEIVED_DATE            DECISION_DATE  \
# 0  2020-10-20 09:20:32.010  2020-11-09 00:00:00.000
#
#   TYPE_OF_EMPLOYER_APPLICATION H2A_LABOR_CONTRACTOR NATURE_OF_TEMPORARY_NEED  \
# 0          Individual Employer                    Y                 Seasonal
#
#   EMERGENCY_FILING   EMPLOYER_NAME TRADE_NAME_DBA  ...       City, State  \
# 0                Y  RAFAEL BARAJAS            NaN  ...  Sebring, Florida
#
#                           Violation Duration Start date   End date  \
# 0  Non-payment of certification fee   1 year  9/23/2016  9/22/2017
#
#   is_repeated violation_number  is_dup  name_changed_y  _merge
# 0       False              1.0   False           False    both
#
# [1 rows x 151 columns]

# %% [markdown]
# # 3. Optional extra credit 1: regex to separate companies from individuals (1 point)
#
# You notice some employers in `debar_clean` have both the name of the company and the name of individual, e.g.:
#
# COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*
#
# Use the uppercase/cleaned `name_clean` in `debar_clean`
#
# A. Write a regex pattern that does the following:
#     - Captures the pattern that occurs before COMPANY if (COMPANY) is in string; so in example above, extracts COUNTY FAIR FARM
#     - Captures the pattern that occurs before INDIVIDUAL if (INDIVIDUAL) is also in string -- so in above, extracts ANDREW WILLIAMSON (so omit the "and")
#
# B. Test the pattern on `pos_example` and `neg_example`-- make sure former returns a list (if using find.all) or match object (if using re.search) with the company name and individual name separated out; make sure latter returns empty
#
# **Hints and resources**: for step A, you can either use re.search, re.match, or re.findall; don't worry about matching B&R Harvesting and Paul Cruz (Individual)
#
# - Same regex resources as above

# %%
pos_example = "COUNTY FAIR FARM (COMPANY) AND ANDREW WILLIAMSON (INDIVIDUAL)*"
neg_example = "CISCO PRODUCE INC"

## your code here to define the pattern

## your code here to apply it to the pos_example

## your code here to apply it to the negative example

# %% [markdown]
# C. Iterate over the `name_clean` column in debar and use regex to create two new columns in `debar_clean`:
#    - `co_name`: A column for company (full `name_clean` string if no match; pattern before COMPANY if one extracted)
#    - `ind_name`: A column for individual (full `name_clean` string if no match; pattern before INDIVIDUAL if one extracted)

# %%
# your code here

# %% [markdown]
#
# D. Print three columns for the rows in `debar_clean` containing the negative example and positive example described above (county fair farm and cisco produce):
#
# - `name_clean`
# - `co_name`
# - `ind_name`
# - `Violation`
#
# **Note**: as shown in the outcome there may be duplicates of the same company reflecting different violations

# %%
# your code here

# %% [markdown]
# # 4. Optional extra credit 2 (up to 3 points)
#
# - For 1 point extra credit, create a visualization with 1+ of the existing fields in either the raw `jobs` or `debar` data. We'll be showing cool visualizations in class so use your imagination! Options could include visualizing between-state or over-time variation
#
# - For 3 points extra credit instead, geocode the employer addresses in `jobs` and plot the addresses of jobs as points overlaid on top of a map of Georgia
#     - **Note**: this extra credit involves Googling since we have not yet covered spatial data.
#         - For discussion of how to geocode addresses -> lat/long, see: https://www.natasshaselvaraj.com/a-step-by-step-guide-on-geocoding-in-python/
#         - For discussion of plotting lat/long dots against a map, see this discussion of geopandas: https://towardsdatascience.com/plotting-maps-with-geopandas-428c97295a73
#     - Relevant columns include `EMPLOYER_ADDRESS_1`
#     - The geocoding might have a long runtime so feel free to implement it in a separate .py script that you submit alongside your notebook and to just read in the geocoded data

# %%
## your code here
